# %%
from langchain_community.document_loaders import YoutubeLoader

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=XfpMkf4rD6E&t=477s", add_video_info=True
)
loader.load()
# Out:
# [Document(page_content='LADIES AND GENTLEMEN, PEDRO PASCAL! [ CHEERS AND APPLAUSE ] >> THANK YOU, THANK YOU. THANK YOU VERY MUCH. I\'M SO EXCITED TO BE HERE. THANK YOU. I SPENT THE LAST YEAR SHOOTING A SHOW CALLED "THE LAST OF US" ON HBO. FOR SOME HBO SHOES, YOU GET TO SHOOT IN A FIVE STAR ITALIAN RESORT SURROUNDED BY BEAUTIFUL PEOPLE, BUT I SAID, NO, THAT\'S TOO EASY. I WANT TO SHOOT IN A FREEZING CANADIAN FOREST WHILE BEING CHASED AROUND BY A GUY WHOSE HEAD LOOKS LIKE A GENITAL WART. IT IS AN HONOR BEING A PART OF THESE HUGE FRANCHISEs LIKE "GAME OF THRONES" AND "STAR WARS," BUT I\'M STILL GETTING USED TO PEOPLE RECOGNIZING ME. THE OTHER DAY, A GUY STOPPED ME ON THE STREET AND SAYS, MY SON LOVES "THE MANDALORIAN" AND THE NEXT THING I KNOW, I\'M FACE TIMING WITH A 6-YEAR-OLD WHO HAS NO IDEA WHO I AM BECAUSE MY CHARACTER WEARS A MASK THE ENTIRE SHOW. THE GUY IS LIKE, DO THE MANDO VOICE, BUT IT\'S LIKE A BEDROOM VOICE. WITHOUT THE MASK, IT JUST SOUNDS PORNY. PEOPLE WALKING BY ON THE S
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# https://www.youtube.com/watch?v=XfpMkf4rD6E&t=477s
    
    
video_id = "XfpMkf4rD6E"

ans = YouTubeTranscriptApi.get_transcript(video_id)

# %%
ans
# Out:
# [{'text': 'hi everyone welcome to cs25 Transformers',
#   'start': 5.759,
#   'duration': 4.081},
#  {'text': 'United video', 'start': 8.639, 'duration': 2.641},
#  {'text': 'this was a course that was solid', 'start': 9.84, 'duration': 3.6},
#  {'text': 'Stanford in the winter 2023', 'start': 11.28, 'duration': 3.899},
#  {'text': 'this course is not about robots that can',
#   'start': 13.44,
#   'duration': 3.179},
#  {'text': 'transform into cars as this picture',
#   'start': 15.179,
#   'duration': 3.6},
#  {'text': "might suggest rather it's about deep",
#   'start': 16.619,
#   'duration': 3.781},
#  {'text': 'learning models that have taken the',
#   'start': 18.779,
#   'duration': 2.881},
#  {'text': 'World by the storm and have', 'start': 20.4, 'duration': 2.639},
#  {'text': 'revolutionized the field of AI and',
#   'start': 21.66,
#   'duration': 3.24},
#  {'text': 'others starting from natural language',
#   'start': 23.039,
#   'duration': 3.181},
# ...

# %%
from datetime import datetime, timedelta

from datetime import datetime, timedelta

def format_time(seconds):
    # Convert seconds to timedelta object
    delta = timedelta(seconds=seconds)
    # Extract hours, minutes, and seconds
    hours, remainder = divmod(delta.seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    # Format the time as HH:MM:SS
    formatted_time = '{:02}:{:02}:{:02}'.format(hours, minutes, seconds)
    return formatted_time

def combine_transcript(transcript):
    combined_transcript = []
    current_interval_start = transcript[0]['start']
    current_interval_text = ""

    for item in transcript:
        if item['start'] - current_interval_start > 900:  # Check if 5 minutes have passed
            duration = item['start'] - current_interval_start
            combined_transcript.append({
                'text': current_interval_text.strip(),
                'start': format_time(current_interval_start),
                'end': format_time(current_interval_start + duration),
                'duration': format_time(duration)
            })
            current_interval_start = item['start']
            current_interval_text = ""

        current_interval_text += item['text'] + " "

    # Append the remaining text as the last interval
    duration = transcript[-1]['start'] - current_interval_start
    combined_transcript.append({
        'text': current_interval_text.strip(),
        'start': format_time(current_interval_start),
        'end': format_time(current_interval_start + duration),
        'duration': format_time(duration)
    })

    return combined_transcript

# %%
combined_transcript = combine_transcript(ans)

# %%
len(combined_transcript)
# Out:
# 5

# %%
len(combined_transcript)
# Out:
# 15

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=XfpMkf4rD6E&t=477s", add_video_info=True
)
x = loader.load()

# %%
gg= x[0].page_content.split(' ')

# %%
len(gg)
# Out:
# 12771

# %%
# Out:
# "hi everyone welcome to cs25 Transformers United video this was a course that was solid Stanford in the winter 2023 this course is not about robots that can transform into cars as this picture might suggest rather it's about deep learning models that have taken the World by the storm and have revolutionized the field of AI and others starting from natural language processing Transformers have been applied all over from computer vision enforcement learning biology robotics Etc we have an exciting set of videos lined up for you with some truly fascinating speakers skip talks presenting how they're applying Transformers to the research in different fields and areas we hope you'll enjoy and learn from these videos so without any further Ado let's get started this is a purely introductory lecture and we'll go into the building blocks of Transformers so first let's start with introducing the instructors uh so for me I'm currently on a temporary data Pro from the PHD program and I'm leading
# ...

# %%
import tiktoken
# To get the tokeniser corresponding to a specific model in the OpenAI API:

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string(combined_transcript[1]['text'], "cl100k_base")
# Out:
# 2224

# %%
len(enc.encode('hello worlds'))
# Out:
# 2

# %%
combined_transcript[0]['text']
# Out:
# "hi everyone welcome to cs25 Transformers United video this was a course that was solid Stanford in the winter 2023 this course is not about robots that can transform into cars as this picture might suggest rather it's about deep learning models that have taken the World by the storm and have revolutionized the field of AI and others starting from natural language processing Transformers have been applied all over from computer vision enforcement learning biology robotics Etc we have an exciting set of videos lined up for you with some truly fascinating speakers skip talks presenting how they're applying Transformers to the research in different fields and areas we hope you'll enjoy and learn from these videos so without any further Ado let's get started this is a purely introductory lecture and we'll go into the building blocks of Transformers so first let's start with introducing the instructors uh so for me I'm currently on a temporary data Pro from the PHD program and I'm leading
# ...

# %%
from openai import OpenAI

client = OpenAI(
        # defaults to os.environ.get("OPENAI_API_KEY")
#         api_key=os.getenv('OPENAI_API_KEY')
    )

messages = [
    {"role": "system", "content": "You are tasked with generating concise notes from a partial transcript of a YouTube video."},
    {"role": "user", "content": f"""Generate organized notes summarizing the key points, main ideas, and relevant details from the following transcript: {combined_transcript[0]['text']} Transcript Range: {combined_transcript[0]['start']} - {combined_transcript[0]['end']} You should mention this range at the top of your answer. Provide headings, sub-heading for the notes where needed.  You should provide proper heading for the notes. If certain notes are lengthy, you are allowed to break it down into sub-headings. Keep the notes clear, concise, and easily comprehensible. You should mention the transcript range at the top. If the transcript is cut off, only generate notes for the available content. Please give your response in markdown syntax."""},
]

chat_completion = client.chat.completions.create(
            messages=messages, model='gpt-3.5-turbo'
        )

final_ans = chat_completion.choices[0].message.content

# %%
combined_transcript[0]['start']
# Out:
# '00:00:05'

# %%
print(final_ans)
# Out:
# # CS25 Transformers United - Introductory Lecture Notes
#
# ## Course Overview
# - Course offers an introduction to Transformers, deep learning models that have revolutionized AI.
# - Transformers have applications in various fields like natural language processing, computer vision, reinforcement learning, biology, and robotics.
# - The course features videos with speakers discussing how Transformers are applied in different research areas.
# - The instructors introduce themselves and their research interests.
#
# ## Key Points about Transformers
# - Transformers are deep learning models that use self-attention mechanisms.
# - They have become extensively used in machine learning and have shown promising results.
# - Transformers excel at encoding context and making context predictions.
# - They have been applied to various problems and have shown improvements over previous models.
#
# ## Transformer Timeline
# - Attention mechanism was introduced in 2017 with the Transformer paper.
# ...

# %%
print(final_ans)
# Out:
# # CS25 Transformers United Video
#
# ## Introduction
# - Course offered at Stanford in winter 2023
# - Not about robots transforming into cars, but about deep learning models
# - Transformers have revolutionized the field of AI and have applications in various fields
#
# ## Overview
# - Exciting set of videos with speakers discussing how Transformers are applied in different fields
# - Topics include natural language processing, computer vision, reinforcement learning, biology, and robotics
#
# ## Introducing the Instructors
# - PHD program data Pro leading an AI robotics startup
# - Research interests in robotics, building assistive learning algorithms
# - Prior experience in NLP research, recently delving into computer vision
# - Martial arts, bodybuilding, K-dramas, anime, occasional gamer
# - Excitement about teaching the class based on previous experience
#
# ## What to Expect in the Class
# - Learn how Transformers work and their applications in machine learning
# ...

# %%
print(final_ans)
# Out:
# ### Where the Transformer Came From
#
# - 2003: A paper on neural networks applied to language modeling, using multi-layer perceptrons to predict the next word in a sequence
# - 2014: Sequence to sequence paper introduced LSTM networks for machine translation, allowing variable-sized input
# - Identified encoder bottleneck: The encoder had to compress the entire input sentence into a single vector, which was too much information
# - Proposed solution: Soft search mechanism to allow the decoder to look back at the encoder's words via an attention mechanism
# - 2017: "Attention is All You Need" paper introduced the Transformer architecture, which focused solely on attention and removed RNN layers
# - Transformer architecture has proven to be resilient and has become the foundation for many subsequent models
# - The attention mechanism facilitates communication between nodes in a directed graph, where each node has a private data vector and can emit keys, queries, and values
# ...

# %%
combined_transcript[0]
# Out:
# {'text': "hi everyone welcome to cs25 Transformers United video this was a course that was solid Stanford in the winter 2023 this course is not about robots that can transform into cars as this picture might suggest rather it's about deep learning models that have taken the World by the storm and have revolutionized the field of AI and others starting from natural language processing Transformers have been applied all over from computer vision enforcement learning biology robotics Etc we have an exciting set of videos lined up for you with some truly fascinating speakers skip talks presenting how they're applying Transformers to the research in different fields and areas we hope you'll enjoy and learn from these videos so without any further Ado let's get started this is a purely introductory lecture and we'll go into the building blocks of Transformers so first let's start with introducing the instructors uh so for me I'm currently on a temporary data Pro from the PHD program and I'
# ...

# %%
import asyncio
from openai import OpenAI

client = OpenAI()

async def generate_notes(transcript):
    messages = [
        {"role": "system", "content": "You are tasked with generating concise notes from a partial transcript of a YouTube video."},
        {"role": "user", "content": f"""Generate organized notes summarizing the key points, main ideas, and relevant details from the following transcript: {transcript['text']} Transcript Range: {transcript['start']} - {transcript['end']} . Provide headings, sub-heading for the notes where needed.  You should provide proper heading for the notes. If certain notes are lengthy, you are allowed to break it down into sub-headings. Keep the notes clear, concise, and easily comprehensible. You should mention the transcript range at the top. If the transcript is cut off, only generate notes for the available content. Please give your response in markdown syntax."""},
    ]
    chat_completion =  client.chat.completions.create(messages=messages, model='gpt-3.5-turbo')
    return chat_completion.choices[0].message.content

async def generate_all():
    tasks = [generate_notes(transcript) for transcript in combined_transcript]
    results = await asyncio.gather(*tasks)
    return results

# Run the main function
# final_notes = asyncio.run(main())

results = await generate_all()

# %%
results
# Out:
# ['# CS25 Transformers United Video Notes\n\n## Introduction\n- CS25 Transformers United is a course offered by Stanford in the winter of 2023.\n- The course focuses on deep learning models known as Transformers.\n- Transformers have revolutionized the field of AI and have applications in natural language processing, computer vision, reinforcement learning, biology, robotics, and more.\n\n## Instructors\n- The instructors leading the course are a PhD student and a master\'s student.\n- They have research interests in robotics, assistive learning algorithms, natural language processing, and computer vision.\n\n## Course Overview\n- The course will cover the basics of Transformers.\n- It will explore the building blocks of Transformers, including the self-attention mechanism.\n- The instructors have lined up a series of videos with speakers discussing how Transformers are applied in various research fields.\n\n## Historical Context of Transformers\n- Transformers gained popularity in 20
# ...

# %%
for i in results:
    print(i)
# Out:
# # CS25 Transformers United Video Notes
#
# ## Introduction
# - CS25 Transformers United is a course offered by Stanford in the winter of 2023.
# - The course focuses on deep learning models known as Transformers.
# - Transformers have revolutionized the field of AI and have applications in natural language processing, computer vision, reinforcement learning, biology, robotics, and more.
#
# ## Instructors
# - The instructors leading the course are a PhD student and a master's student.
# - They have research interests in robotics, assistive learning algorithms, natural language processing, and computer vision.
#
# ## Course Overview
# - The course will cover the basics of Transformers.
# - It will explore the building blocks of Transformers, including the self-attention mechanism.
# - The instructors have lined up a series of videos with speakers discussing how Transformers are applied in various research fields.
#
# ## Historical Context of Transformers
# ...
